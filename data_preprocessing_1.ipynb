# %% [raw]
# # import libraries
# import pandas as pd
# import numpy as np
#
# # get the data from csv file to dataframe
# raw_data = pd.read_csv('data/amazon_datafiniti.csv', low_memory=False)
#
# # check ctolumn name
# raw_data.columns

# %%
raw_data.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# ...

# %%
# check unique username and goods name
user_count = raw_data['reviews.username'].unique().shape[0]
item_count = raw_data['name'].unique().shape[0]

print("user count: " + str(user_count) + ", item count: " + str(item_count))
# Out:
# user count: 3815, item count: 23

# %%
raw_data.shape
# Out:
# (5000, 24)

# %%
# make item table
itemdf = pd.DataFrame()
itemid = []
itemname = list(set(raw_data['name']))
itemdf['itemname'] = itemname
itemdf.insert(0, 'itemId', range(1, 1 + len(itemname)))
itemdf
# Out:
#     itemId                                           itemname
# 0        1  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...
# 1        2  Amazon Fire TV with 4K Ultra HD and Alexa Voic...
# 2        3  Amazon 9W PowerFast Official OEM USB Charger a...
# 3        4  Fire Tablet, 7 Display, Wi-Fi, 16 GB - Include...
# 4        5  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...
# 5        6  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 6        7  Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...
# 7        8  Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 ...
# 8        9  Kindle E-reader - White, 6 Glare-Free Touchscr...
# 9       10  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 10      11  Amazon Tap - Alexa-Enabled Portable Bluetooth ...
# 11      12  Amazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Black
# 12      13  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...
# 13      14  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...
# ...

# %%
# make user table
userdf = pd.DataFrame()
userid = []
username = list(set(raw_data['reviews.username']))
userdf['username'] = username
userdf.insert(0, 'userId', range(1, 1 + len(username)))
userdf
# Out:
#       userId         username
# 0          1             bear
# 1          2            Isaac
# 2          3           Andrea
# 3          4            JWF46
# 4          5           ChrisH
# 5          6           booboo
# 6          7            barom
# 7          8      Bucsfanatic
# 8          9           Rjob74
# 9         10             Rami
# 10        11           B61MD1
# 11        12             Marg
# 12        13           zephyr
# 13        14           Spanky
# 14        15            Sfcc6
# 15        16            Eicfi
# 16        17            OKyES
# 17        18           dpeter
# 18        19        Josaphine
# 19        20         Tpc88888
# 20        21        BradmanTX
# 21        22             Zoom
# 22        23      gadgetguy11
# 23        24             fuji
# 24        25         Talia501
# 25        26         nebrando
# 26        27        Tgiberson
# 27        28          funfam3
# 28        29  ConsistentBuyer
# 29        30           GoBlue
# ...

# %%
data_reviews = raw_data[
    ['name', 
     'reviews.username',
     'reviews.rating', 
     'reviews.text']
]
data_reviews.head()
# Out:
#                                                 name reviews.username  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...           llyyue
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...           Charmi
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...     johnnyjojojo
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...          Kdperry
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...      Johnnyblack
#
#    reviews.rating                                       reviews.text
# 0               3  I thought it would be as big as small paper bu...
# 1               5  This kindle is light and easy to use especiall...
# 2               4  Didnt know how much i'd use a kindle so went f...
# 3               5  I am 100 happy with my purchase. I caught it o...
# 4               5  Solid entry level Kindle. Great for kids. Gift...

# %%
reviewsdf= pd.merge(data_reviews, itemdf, how='left',
                    left_on='name', right_on='itemname')
reviewsdf= pd.merge(reviewsdf, userdf, how='left',
                    left_on='reviews.username', 
                    right_on='username')
reviewsdf.head()
# Out:
#                                                 name reviews.username  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...           llyyue
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...           Charmi
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...     johnnyjojojo
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...          Kdperry
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...      Johnnyblack
#
#    reviews.rating                                       reviews.text  itemId  \
# 0               3  I thought it would be as big as small paper bu...      19
# 1               5  This kindle is light and easy to use especiall...      19
# 2               4  Didnt know how much i'd use a kindle so went f...      19
# 3               5  I am 100 happy with my purchase. I caught it o...      19
# 4               5  Solid entry level Kindle. Great for kids. Gift...      19
#
#                                             itemname  userId      username
# ...

# %%
reviewsdf.columns
# Out:
# Index(['name', 'reviews.username', 'reviews.rating', 'reviews.text', 'itemId',
#        'itemname', 'userId', 'username'],
#       dtype='object')

# %%
# Data Reduction

# remove reapeted column
reviewsdf.drop(['name', 
                'reviews.username', 
                'itemname', 'username'], axis=1,
               inplace = True)

reviewsdf.head()
# Out:
#    reviews.rating                                       reviews.text  itemId  \
# 0               3  I thought it would be as big as small paper bu...      19
# 1               5  This kindle is light and easy to use especiall...      19
# 2               4  Didnt know how much i'd use a kindle so went f...      19
# 3               5  I am 100 happy with my purchase. I caught it o...      19
# 4               5  Solid entry level Kindle. Great for kids. Gift...      19
#
#    userId
# 0    2976
# 1    3339
# 2    1472
# 3     603
# 4     332

# %%
# rename the columns
reviewsdf.rename(
    columns={
        'itemId':'itemId',
        'userId': 'userId',
        'reviews.rating': 'rating', 
        'reviews.text': 'testimony'}, 
    inplace=True)

reviewsdf.head()
# Out:
#    rating                                          testimony  itemId  userId
# 0       3  I thought it would be as big as small paper bu...      19    2976
# 1       5  This kindle is light and easy to use especiall...      19    3339
# 2       4  Didnt know how much i'd use a kindle so went f...      19    1472
# 3       5  I am 100 happy with my purchase. I caught it o...      19     603
# 4       5  Solid entry level Kindle. Great for kids. Gift...      19     332

# %%
# check the total reviews of each item before duplicate detected
# check_reviews_subtotal_bef_dup = reviewsdf.groupby(['itemId']).count()
# check_reviews_subtotal_bef_dup

# %%
# sub total review before remove duplicate
# itemdf['bef_subtotal_review']=[x for x in check_reviews_subtotal_bef_dup.rating]
# itemdf

# %%
# reviewsdf.shape

# %%
print(reviewsdf.duplicated().sum())
# Out:
# 195

# %%
# drop duplicate data
reviewsdf.drop_duplicates(keep="last", inplace=True)
reviewsdf.shape
# Out:
# (4805, 4)

# %%
# check the total reviews of each item after duplicate detected
check_reviews_subtotal = reviewsdf.groupby(['itemId']).count()
check_reviews_subtotal
# Out:
#         rating  testimony  userId
# itemId
# 1          418        418     418
# 2           22         22      22
# 3           40         40      40
# 4           24         24      24
# 5           32         32      32
# 6          556        556     556
# 7          101        101     101
# 8          225        225     225
# 9            4          4       4
# 10          96         96      96
# 11         217        217     217
# 12          67         67      67
# 13          96         96      96
# 14          21         21      21
# 15          58         58      58
# 16          53         53      53
# 17         140        140     140
# 18          45         45      45
# 19         590        590     590
# 20         751        751     751
# 21         796        796     796
# 22          82         82      82
# 23         371        371     371

# %%
# sub total review after remove duplicate
itemdf['subtotal_review']=[x for x in check_reviews_subtotal.rating]
itemdf
# Out:
#     itemId                                           itemname  \
# 0        1  Brand New Amazon Kindle Fire 16gb 7" Ips Displ...
# 1        2  Amazon 9W PowerFast Official OEM USB Charger a...
# 2        3  All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...
# 3        4  Kindle Oasis E-reader with Leather Charging Co...
# 4        5  Kindle Oasis E-reader with Leather Charging Co...
# 5        6  Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...
# 6        7  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...
# 7        8  Amazon Tap - Alexa-Enabled Portable Bluetooth ...
# 8        9  Amazon Fire TV with 4K Ultra HD and Alexa Voic...
# 9       10  Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 ...
# 10      11  Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...
# 11      12  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 12      13  Amazon Kindle E-Reader 6" Wifi (8th Generation...
# 13      14  Amazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Black
# ...

# %%
reviewsdf.head()
# Out:
#    rating                                          testimony  itemId  userId
# 0       3  I thought it would be as big as small paper bu...      19    2976
# 1       5  This kindle is light and easy to use especiall...      19    3339
# 2       4  Didnt know how much i'd use a kindle so went f...      19    1472
# 3       5  I am 100 happy with my purchase. I caught it o...      19     603
# 4       5  Solid entry level Kindle. Great for kids. Gift...      19     332

# %%
# save reviews 
reviewsdf.to_csv("data/reviews.csv")
# save the itemdf to csv file
itemdf.to_csv("data/item.csv")
# save the userdf to csv file
userdf.to_csv("data/user.csv")
